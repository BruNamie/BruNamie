# %%
APPNAME = 'PhotoEditor'

# %%
# Training data
# !wget https://raw.githubusercontent.com/BruNamie/RE-BERT/main/datasets_iob/train_iob_{APPNAME}.txt

# Testing data
# !wget https://raw.githubusercontent.com/BruNamie/RE-BERT/main/datasets_iob/test_data_{APPNAME}.txt

# True labels (for evaluation)
# !wget https://raw.githubusercontent.com/BruNamie/RE-BERT/main/datasets_iob/test_label_{APPNAME}.txt
# Out:
# --2022-10-20 18:55:01--  https://raw.githubusercontent.com/BruNamie/RE-BERT/main/datasets_iob/train_iob_PhotoEditor.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1727866 (1.6M) [text/plain]
# Saving to: ‘train_iob_PhotoEditor.txt’
#
# train_iob_PhotoEdit 100%[===================>]   1.65M  --.-KB/s    in 0.04s
#
# 2022-10-20 18:55:02 (39.5 MB/s) - ‘train_iob_PhotoEditor.txt’ saved [1727866/1727866]
#
# --2022-10-20 18:55:02--  https://raw.githubusercontent.com/BruNamie/RE-BERT/main/datasets_iob/test_data_PhotoEditor.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7072 (6.9K) [text/plain]
# Saving to: ‘test_data_PhotoEditor.txt’
#
# test_data_PhotoEdit 100%[===================>]   6.91K  --.-KB/s    in 0s
#
# 2022-10-20 18:55:02 (94.0 MB/s) - ‘test_data_PhotoEditor.txt’ saved [7072/7072]
#
# --2022-10-20 18:55:02--  https://raw.githubusercontent.com/BruNamie/RE-BERT/main/datasets_iob/test_label_PhotoEditor.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1425 (1.4K) [text/plain]
# Saving to: ‘test_label_PhotoEditor.txt’
#
# test_label_PhotoEdi 100%[===================>]   1.39K  --.-KB/s    in 0s
#
# 2022-10-20 18:55:02 (26.8 MB/s) - ‘test_label_PhotoEditor.txt’ saved [1425/1425]

# %%
# !git clone https://github.com/BruNamie/RE-BERT
# !mv RE-BERT/* .
# Out:
# fatal: destination path 'RE-BERT' already exists and is not an empty directory.
# mv: cannot stat 'RE-BERT/*': No such file or directory

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.12.1+cu113)
# Requirement already satisfied: transformers==2.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from transformers==2.3.0->-r requirements.txt (line 3)) (4.64.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==2.3.0->-r requirements.txt (line 3)) (0.0.53)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from transformers==2.3.0->-r requirements.txt (line 3)) (1.24.94)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers==2.3.0->-r requirements.txt (line 3)) (0.1.97)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.3.0->-r requirements.txt (line 3)) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.3.0->-r requirements.txt (line 3)) (2022.6.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.0->-r requirements.txt (line 2)) (4.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->-r requirements.txt (line 4)) (1.0.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers==2.3.0->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.94 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers==2.3.0->-r requirements.txt (line 3)) (1.27.94)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers==2.3.0->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.94->boto3->transformers==2.3.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.94->boto3->transformers==2.3.0->-r requirements.txt (line 3)) (1.25.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.94->boto3->transformers==2.3.0->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.3.0->-r requirements.txt (line 3)) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.3.0->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.3.0->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.3.0->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.3.0->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->-r requirements.txt (line 4)) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->-r requirements.txt (line 4)) (3.1.0)

# %%
# !python train.py --dataset {APPNAME} --train_file train_iob_{APPNAME}.txt
# Out:
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# INFO:transformers.configuration_utils:Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# INFO:transformers.modeling_utils:loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# INFO:root:cuda memory allocated: 455604736
# cuda memory allocated: 455604736
# INFO:root:> n_trainable_params: 113617923, n_nontrainable_params: 0
# > n_trainable_params: 113617923, n_nontrainable_params: 0
# INFO:root:> training arguments:
# > training arguments:
# INFO:root:>>> model_name: RE_BERT
# >>> model_name: RE_BERT
# INFO:root:>>> dataset: PhotoEditor
# >>> dataset: PhotoEditor
# INFO:root:>>> train_file: train_iob_PhotoEditor.txt
# >>> train_file: train_iob_PhotoEditor.txt
# INFO:root:>>> optimizer: <class 'torch.optim.adam.Adam'>
# >>> optimizer: <class 'torch.optim.adam.Adam'>
# INFO:root:>>> initializer: <function xavier_uniform_ at 0x7f703bf35c20>
# >>> initializer: <function xavier_uniform_ at 0x7f703bf35c20>
# INFO:root:>>> lr: 2e-05
# >>> lr: 2e-05
# INFO:root:>>> dropout: 0.1
# >>> dropout: 0.1
# INFO:root:>>> l2reg: 0.01
# >>> l2reg: 0.01
# INFO:root:>>> num_epoch: 1
# >>> num_epoch: 1
# INFO:root:>>> batch_size: 16
# >>> batch_size: 16
# INFO:root:>>> log_step: 10
# >>> log_step: 10
# INFO:root:>>> bert_dim: 768
# >>> bert_dim: 768
# INFO:root:>>> pretrained_bert_name: bert-base-uncased
# >>> pretrained_bert_name: bert-base-uncased
# INFO:root:>>> max_seq_len: 80
# >>> max_seq_len: 80
# INFO:root:>>> requirement_dim: 3
# >>> requirement_dim: 3
# INFO:root:>>> hops: 3
# >>> hops: 3
# INFO:root:>>> patience: 5
# >>> patience: 5
# INFO:root:>>> device: cuda
# >>> device: cuda
# INFO:root:>>> seed: None
# >>> seed: None
# INFO:root:>>> valset_ratio: 0
# >>> valset_ratio: 0
# INFO:root:>>> local_context_focus: cdm
# >>> local_context_focus: cdm
# INFO:root:>>> alpha: 3
# >>> alpha: 3
# INFO:root:>>> SRD: 3
# >>> SRD: 3
# INFO:root:>>> model_class: <class 'models.re_bert.RE_BERT'>
# >>> model_class: <class 'models.re_bert.RE_BERT'>
# INFO:root:>>> dataset_file: {'train': 'train_iob_PhotoEditor.txt'}
# >>> dataset_file: {'train': 'train_iob_PhotoEditor.txt'}
# INFO:root:>>> inputs_cols: ['concat_bert_indices', 'concat_segments_indices', 'text_bert_indices', 'aspect_bert_indices']
# >>> inputs_cols: ['concat_bert_indices', 'concat_segments_indices', 'text_bert_indices', 'aspect_bert_indices']
# INFO:root:>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# INFO:root:epoch: 1
# epoch: 1
# INFO:root:loss: 0.7786
# loss: 0.7786
# INFO:root:loss: 0.7834
# loss: 0.7834
# INFO:root:loss: 0.7970
# loss: 0.7970
# INFO:root:loss: 0.7834
# loss: 0.7834
# INFO:root:loss: 0.7781
# loss: 0.7781
# INFO:root:loss: 0.7624
# loss: 0.7624
# INFO:root:loss: 0.7582
# loss: 0.7582
# INFO:root:loss: 0.7530
# loss: 0.7530
# INFO:root:loss: 0.7573
# loss: 0.7573
# INFO:root:loss: 0.7620
# loss: 0.7620
# INFO:root:loss: 0.7587
# loss: 0.7587
# INFO:root:loss: 0.7543
# loss: 0.7543
# INFO:root:loss: 0.7499
# loss: 0.7499
# INFO:root:loss: 0.7338
# loss: 0.7338
# INFO:root:loss: 0.7265
# loss: 0.7265
# INFO:root:loss: 0.7214
# loss: 0.7214
# INFO:root:loss: 0.7244
# loss: 0.7244
# INFO:root:loss: 0.7229
# loss: 0.7229
# INFO:root:loss: 0.7096
# loss: 0.7096
# INFO:root:loss: 0.7028
# loss: 0.7028
# INFO:root:loss: 0.6965
# loss: 0.6965
# INFO:root:loss: 0.6913
# loss: 0.6913
# INFO:root:loss: 0.6890
# loss: 0.6890
# INFO:root:loss: 0.6820
# loss: 0.6820
# INFO:root:loss: 0.6775
# loss: 0.6775
# INFO:root:loss: 0.6716
# loss: 0.6716
# INFO:root:loss: 0.6689
# loss: 0.6689
# INFO:root:loss: 0.6619
# loss: 0.6619
# INFO:root:loss: 0.6563
# loss: 0.6563
# INFO:root:loss: 0.6513
# loss: 0.6513
# INFO:root:loss: 0.6481
# loss: 0.6481
# INFO:root:loss: 0.6435
# loss: 0.6435
# INFO:root:loss: 0.6377
# loss: 0.6377
# INFO:root:loss: 0.6333
# loss: 0.6333
# INFO:root:loss: 0.6300
# loss: 0.6300
# INFO:root:loss: 0.6262
# loss: 0.6262
# INFO:root:loss: 0.6205
# loss: 0.6205
# INFO:root:loss: 0.6176
# loss: 0.6176
# INFO:root:loss: 0.6124
# loss: 0.6124
# INFO:root:loss: 0.6081
# loss: 0.6081
# INFO:root:loss: 0.6059
# loss: 0.6059
# INFO:root:loss: 0.6023
# loss: 0.6023
# INFO:root:loss: 0.5980
# loss: 0.5980
# INFO:root:loss: 0.5952
# loss: 0.5952
# INFO:root:loss: 0.5925
# loss: 0.5925
# INFO:root:loss: 0.5880
# loss: 0.5880
# INFO:root:loss: 0.5865
# loss: 0.5865
# INFO:root:loss: 0.5840
# loss: 0.5840
# INFO:root:loss: 0.5785
# loss: 0.5785
# INFO:root:loss: 0.5750
# loss: 0.5750
# INFO:root:loss: 0.5704
# loss: 0.5704
# INFO:root:loss: 0.5675
# loss: 0.5675
# INFO:root:loss: 0.5631
# loss: 0.5631
# INFO:root:loss: 0.5601
# loss: 0.5601
# INFO:root:loss: 0.5573
# loss: 0.5573
# INFO:root:loss: 0.5529
# loss: 0.5529
# INFO:root:loss: 0.5486
# loss: 0.5486
# INFO:root:loss: 0.5456
# loss: 0.5456
# INFO:root:loss: 0.5431
# loss: 0.5431
# INFO:root:loss: 0.5420
# loss: 0.5420
# INFO:root:loss: 0.5411
# loss: 0.5411
# INFO:root:loss: 0.5380
# loss: 0.5380
# INFO:root:loss: 0.5350
# loss: 0.5350
# INFO:root:loss: 0.5324
# loss: 0.5324
# INFO:root:loss: 0.5297
# loss: 0.5297
# INFO:root:loss: 0.5266
# loss: 0.5266
# INFO:root:loss: 0.5254
# loss: 0.5254
# INFO:root:loss: 0.5236
# loss: 0.5236
# INFO:root:loss: 0.5222
# loss: 0.5222
# INFO:root:loss: 0.5198
# loss: 0.5198
# INFO:root:loss: 0.5182
# loss: 0.5182
# INFO:root:loss: 0.5164
# loss: 0.5164
# INFO:root:loss: 0.5135
# loss: 0.5135
# INFO:root:loss: 0.5101
# loss: 0.5101
# INFO:root:loss: 0.5073
# loss: 0.5073
# INFO:root:loss: 0.5040
# loss: 0.5040
# INFO:root:loss: 0.5017
# loss: 0.5017
# INFO:root:loss: 0.4993
# loss: 0.4993
# INFO:root:loss: 0.4982
# loss: 0.4982
# INFO:root:loss: 0.4958
# loss: 0.4958
# INFO:root:loss: 0.4940
# loss: 0.4940
# INFO:root:loss: 0.4924
# loss: 0.4924
# INFO:root:loss: 0.4917
# loss: 0.4917
# INFO:root:loss: 0.4895
# loss: 0.4895
# INFO:root:loss: 0.4867
# loss: 0.4867
# INFO:root:loss: 0.4848
# loss: 0.4848
# INFO:root:loss: 0.4828
# loss: 0.4828
# INFO:root:loss: 0.4809
# loss: 0.4809
# INFO:root:loss: 0.4799
# loss: 0.4799
# INFO:root:loss: 0.4788
# loss: 0.4788
# INFO:root:loss: 0.4783
# loss: 0.4783
# INFO:root:>> saved: trained_models/RE_BERT_PhotoEditor_iob_epoch_1.model
# >> saved: trained_models/RE_BERT_PhotoEditor_iob_epoch_1.model

# %%
# !python extract.py --test_file test_data_{APPNAME}.txt --classifier_model_file trained_models/RE_BERT_{APPNAME}_iob_epoch_1.model --output_file {APPNAME}_extracted_reqs.txt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# loading model RE_BERT ...
# Test Size: 154
# Extract software requirements candidates:   0% 0/154 [00:00<?, ?it/s]extract.py:72: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   t_inputs = [torch.tensor([data[col]], device=self.opt.device) for col in self.opt.inputs_cols]
# Extract software requirements candidates: 100% 154/154 [00:35<00:00,  4.29it/s]
# Extracted software requirements --> PhotoEditor_extracted_reqs.txt

# %%
reviews_test = open('test_data_'+APPNAME+'.txt', 'r').readlines()
reqs_exracted =  open(APPNAME+'_extracted_reqs.txt', 'r').readlines()
reqs_labeled =  open('test_label_'+APPNAME+'.txt', 'r').readlines()

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

df = pd.DataFrame()
df['review'] = reviews_test
df['labeled (humans)'] = reqs_labeled
df['extracted (re-bert)'] = reqs_exracted
df = df.replace('\n',' ', regex=True)
df
# Out:
#                                                                                                                                                                                                       review  \
# 0                                                                                                                                                                                        May be i can check
# 1                                                                                                                                                                                          It make me happy
# 2                                                               I have a normal phone and it made 1 of my pics look like one of a iphone 6 if u dont believe me look at my instagran account     wings_2004
# 3                                                                                                                                                                                           Love it so much
# 4                                                                                                                                                                                       Cant get to install
# 5                                                                                                                                                              Too many ads and secondly erratic interface
# 6                                                                                                                                                                                I have already uninstalled
# 7                                                                                                                                                                                              Its so happy
# 8                                                                                                                                                                      Nicest systematic for Android phones
# 9                                                                                                                                                                                       Its so easy and fun
# 10                                                                                                                                                                              Main diss app tight um hmmm
# 11                                                                                                                                                                                    Everything is awesome
# 12                                                                                                            Ive downloaded a few different ones and this is easy to use, and the pictures come out great
# 13                                                                                                                         Plenty of options to choose from to make whatever kind of picture you would like
# 14                                                                                                                                                                              Like it but not so cool app
# 15                                                                                                                                   I really like the HD effect, brightness and color correction features
# 16                                                                                                                                           I can basically change the whole pic   its so cool :-) lol :-)
# 17                                                                                                                                                                        I cant  believe  how easy  it is
# 18                                                                                                                                                                  This app is very good for photos editer
# 19                                                                                                                                                                          It is just simple and Good app
# 20                                                                                                                                                                      Its ok but u have to download stuff
# 21                                                          Ive used this on my previous phone worked prrfectly but ive recntly bought samsung galaxy a5 the splash and focus functn doesnt work plz help!!
# 22                                                                                                                                                                                         This is perfect
# 23                                                                                                                                If only you could make a video editor, too, that is just as good as this
# 24                                                                                                                                                                               Makes awesome book covers!
# 25                                                                                                                                                            Theres an ad after every other button I press
# 26                                                                                                                                                                           Its has alot of things awesome
# 27                                                                                                                                                                                     This is awesome app
# 28                                                                                                                                                                                       its alright so far
# 29                                                                                                                                                                   I like how it is fast and easy to use!
# 30                                                                                            lighter and faster than other photo editors ,with many editing options best recommended app for photo editing
# 31                                                                                                                                          super easy and i love the effects ,also super easy to install!!
# 32                                                                                                                                                                                            Very good app
# 33                                                                                                                                                                 The app has very good features indeed
# 34                                                                                                                                                  I would give this app a 5 if there were not so many ads
# 35                                                                                                                                                                                    never use it its fake
# 36                                                                                                                                                                                             Easy to use!
# 37                                                                                                                                                               Covers imperfections and has cool filters!
# 38                                                                                                                                                                             I love did App Its Amazing!!
# 39                                                                                                                                                                                          Its a great app
# 40                                                                                                                                              Very useful, full features without any pro version purchase
# 41                                                                                                                                                                                                I LOVE IT
# 42                                                                               There are so many ads popping up that the app is now unusable because an ad pops up literally every time I close the last
# 43                                                                                                                                                                                          I have used it
# 44                                                                                                                                                                        Its a good app for photo editing
# 45                                                                                                                                                                    You can so many things from this app
# 46                                                                                                                                                               You can download this app without fearing
# 47                                                                                                         I`ve seen so many photo editing tools but this one is the best 10x a lot its really proffesional
# 48                                                                                                                                             I have a blast using this app with my eight yr old daughter!
# 49                                                                                                                                                                     Able to take r add to photo love it!
# 50                                                                                                                                                                First, why do you need Access to my phone
# 51                                                                                                                                                Why are you running in background when i am not using you
# 52                                                                                                                                                                                        Get off my phone!
# 53                                                                                                                                                                Makes neat collages and great for editing
# 54                                                                                                                                   U have t ok down load every thing u want to add to it like the effects
# 55                                                                                                                                                     A powerful photo editor with many wonderfull effects
# 56                                                                                                                                                         Horrible editor, worst app in this entire store
# 57                                                                                                                                            I give it half of no stars, stupid as a pair of inbred babies
# 58                                                                                                                                                               Great Photo Editing App for editing Photos
# 59                                                                                                                                                                  verry nice app and i am happy this apps
# 60                                                                                                                                                                             its a great app to edit pics
# 61                                                                                                                                          Very satisfied with the results I get by using this software :)
# 62                                                                                                                                                                            Helped me make AMAZING photos
# 63                                                                                                                                                                                The best that one can get
# 64                                                                                                           I gave this app a 5 stars cause rate me pls always pops out and its annoying, good app though
# 65                                                                                                                                                                                          Loved using it
# 66                                                                                                                                                                    Cant use d way i use CS6 in my lappy
# 67                                                                                                                                            But its far bettrr than any other apps i tried on my phone
# 68                                                                                                                                                                                Needs an airbrush feature
# 69                                                                                                                                                                        It helps me create amazing fotos
# 70                                                                                                                                        They really need to think outside the box and get more creative
# 71                                                                                                                     think about what makes this app better than any other app and why we should get it
# 72                                                                                                                                                                   thats some advice from a 12 year old
# 73                                                                                                                                                                                      take it or leave it
# 74                                                                                                                                    I would give it 5 stars, but there are a few bugs that could be fixed
# 75                                                                                                                                                              The app has more options than Ill ever use
# 76                                                                                  It doesnt provide for a way to delete previously edited needless photos that are starting to accumulate in the gallery
# 77                                                                                                            Cant obtain any help on how to delete just those photos while maintaining the original photo
# 78                                                                                                                                                                     Ilike it but the other app are busy
# 79                                                                                                                                                                                    But i got the frames
# 80                                                                                                                                                                              The best one I found so far
# 81                                                                                                                                       Love it    Love the enhanced picture qualities, the frames etc
# 82                                                                                                                                                          Easy very nice detail options and doesnt crash!
# 83                                                                                                                                                     Would be better if there were more frame options tho
# 84                                                                                                                                                    Have to download everything and adverts are annoying!
# 85                                                                                                                                                                                                 Its best
# 86                                                                                                                                                                            Best photo editor i have seen
# 87                                                                                                                                                                   Without Aviary this app cannot working
# 88                                                                                                                                                                               Great app     easy to use
# 89                                                                                                                                                                                  But has alot of popups
# 90                                                                                                                                                            Sud have an option to un blur the blur photos
# 91                                                                                                                                                                                 its a cooooool app ever
# 92                                                                                                                                                                                         i like it   !!!!
# 93                                                                                                     Whenever I went to choose a photo then go back to it a blank black screen came up for a few seconds
# 94                                                                                                                  Also it seemed to only let me have one photo I couldnt see how to add in another photo
# 95                                                                                                                                                              The app is gud but reqire sum features more
# 96                                                                                                                                                                        This will be very helpfull to me
# 97                                                                                                                                                            I love being able to have fun  with my photo
# 98                                                                                                                     I can edit in many ways    It looks always perfect    so yea 3 thumbs up to this app
# 99                                                                                                                                                                   It perfects flaws and inperfections !!
# 100                                                                                                                                                                            Lol and its fun to use too!!
# 101                                                                                    App is Brilliant   but only the thing due to which I gave 4 star not 5 is FONT     We cant change the FONT Text
# 102                                                                                                                                                                              Love the affects when done
# 103                                                                                                                                                                     This aap is excellent     Love it
# 104                                                                                                                                                                                 ( It works in my phone)
# 105                                                                                                                                                                                     Doesnt even start
# 106                                                                                                                                                                                      Waste of time
# 107                                                                                                        This works realy well the only thing I dont like about it is that u had to download the stickers
# 108                                                                                                                                                                               Best application in world
# 109                                                                                                                                                  I have used many and this I like one better then many
# 110                                                                                                                                                                     Wish i knew how to change font size
# 111                                                                                                                                                                          I reallly can fix my ugly pics
# 112                                                                                                                                                           This app is pretty cool I think it works good
# 113  Well for one thing your app doesnt look anything like the pictures above and for another I got to edit one photo and then the app wouldnt open and kept force closing I hate it so I removed imedently
# 114                                                                                                                                                                                            Not bad app
# 115                                                                                                                                                              nice editings cn be done overall good job
# 116                                                                                                                                                                                        This is good app
# 117                                                                                                           If they are free, why do I have to install the frames then the effects then other things
# 118                                                                                                                                                                              just make it come with it
# 119                                                                                                                                                                   Suprb app for creating more effect
# 120                                                                                                                                                                                           Like a picart
# 121                                                                                                                                                          I dnt like that u cant redo or format the text
# 122                                                                                                                                                                            It is a great editor love it
# 123                                                                                                                                                                                     I liked it so much
# 124                                                                                                                                                                     You have to pay for stickers really
# 125                                                                                                                                                                           Works very well, easy, loaded
# 126                                                                                                                                                                        Perfect mobile photo editing app
# 127                                                                                                                                                                                         It works for me
# 128                                                                                 East or west this apps is best I try my best to choose some other apps and use them Thanks developer please keep it up
# 129                                                                                                                                         I love it it makes me feel real with the effects n my blue eyes
# 130                                                                                                                                                                                          This is ousome
# 131                                                                                                                                                                                      Cant upload photos
# 132                                                                                                                                                                                Love the new ehancements
# 133                                                                                                                                                This might be good but Im write before playing this app!
# 134                                                                                                                                                                                  Lots better than some
# 135                                                                                                                                                                            Better than default editors
# 136                                                                                                                                                          its easy to use and has a good user interface
# 137                      You have to download everything before you CD an even start date it  so much it is rubbish for not install unless you like rubbish apps ‼‼‼‼‼‼‼‼‼‼‼:-\ :-\ :-\ :-\ :-\ :-\ :-\ :-\
# 138                                                                                                                                                                                  Solid apppp I loved it
# 139                                                                                                                                                                                 Making memes right now!
# 140                                                                                                                                                                            Hope do not make any trouble
# 141                                                                                                                                                                                     Very user friendly
# 142                                                                                                                 needed to take off unwanted bits captured in the photo i took & this app did the trick!
# 143                                                                                                                                                                      Its looks great and nice I like it
# 144                                                                                                                                                                  Exactly the program I was looking for!
# 145                                                                                   I have an HTC One M8 and for some reason this app opens and then closes without out any option for me to do anything
# 146                                                                                                                                       My only question is if this has to do specifically with my phone
# 147                                                                                                                                                      Especially since it seems to work well for others
# 148                                                                                                                                                                                          Very good apps
# 149                                                                                                                                                                                             Easy to use
# 150                                                                                                                                                                                Very good photo edit app
# 151                                                                                                                                                                                       Cool app loved it
# 152                                                                                                                                                                           I loved it//////\\\\\\\$£€$€¥
# 153                                                                                                                                                                              This is a great app to use
#
#                                              labeled (humans)  \
# 0
# 1
# 2                                                       pics
# 3
# 4                                                    install
# 5                                              ads;interface
# 6                                                uninstalled
# 7
# 8
# 9
# 10
# 11
# 12                                                  pictures
# 13      options to choose from;make whatever kind of picture
# 14
# 15          HD effect;brightness correction;color correction
# 16                                      change the whole pic
# 17
# 18                                             photos editer
# 19
# 20
# 21                                splash functn;focus functn
# 22
# 23                                       make a video editor
# 24                                               book covers
# 25
# 26
# 27
# 28
# 29
# 30                       photo editing;photo editors;editing
# 31                                           effects;install
# 32
# 33
# 34                                                       ads
# 35
# 36
# 37                              filters;Covers imperfections
# 38
# 39
# 40
# 41
# 42                                 ads popping up;ad pops up
# 43
# 44                                             photo editing
# 45
# 46
# 47                                             photo editing
# 48
# 49                                   take photo;add to photo
# 50
# 51
# 52
# 53                                                   editing
# 54                                                   effects
# 55                                      photo editor;effects
# 56                                                    editor
# 57
# 58                              Photo Editing;editing Photos
# 59
# 60                                                 edit pics
# 61                                         the results I get
# 62                                       make AMAZING photos
# 63
# 64                               rate me pls always pops out
# 65
# 66
# 67
# 68                                          airbrush feature
# 69                                      create amazing fotos
# 70
# 71
# 72
# 73
# 74
# 75
# 76          delete previously edited needless photos;gallery
# 77   delete just those photos;maintaining the original photo
# 78
# 79                                                    frames
# 80
# 81                         enhanced picture qualities;frames
# 82                                            detail options
# 83                                             frame options
# 84                                                   adverts
# 85
# 86                                              photo editor
# 87
# 88
# 89                                                    popups
# 90                         option to un blur the blur photos
# 91
# 92
# 93                       choose a photo;black screen came up
# 94                                photo;add in another photo
# 95
# 96
# 97                                                     photo
# 98                                                      edit
# 99                     perfects flaws;perfects inperfections
# 100
# 101                                FONT;change the FONT Text
# 102                                                  affects
# 103
# 104
# 105
# 106
# 107                                    download the stickers
# 108
# 109
# 110                                         change font size
# 111                                         fix my ugly pics
# 112
# 113                     pictures;edit one photo;open;closing
# 114
# 115                                                 editings
# 116
# 117                               install the frames;effects
# 118
# 119                                     creating more effect
# 120                                                   picart
# 121                            redo the text;format the text
# 122                                                   editor
# 123
# 124                                                 stickers
# 125
# 126                                            photo editing
# 127
# 128
# 129                                                  effects
# 130
# 131                                            upload photos
# 132                                              ehancements
# 133
# 134
# 135                                                  editors
# 136                                           user interface
# 137                                                  install
# 138
# 139                                             Making memes
# 140
# 141
# 142             take off unwanted bits captured in the photo
# 143
# 144
# 145                                             opens;closes
# 146
# 147
# 148
# 149
# 150                                               photo edit
# 151
# 152
# 153
#
#                                       extracted (re-bert)
# 0                                                  check
# 1
# 2                    pics look;look at;instagran account
# 3
# 4                                                install
# 5                                          ads;interface
# 6                                            uninstalled
# 7
# 8
# 9
# 10
# 11
# 12                                              pictures
# 13             options;choose;make whatever kind;picture
# 14
# 15        HD effect;brightness;color correction features
# 16                                      change;whole pic
# 17
# 18                                         photos editer
# 19
# 20                                                 stuff
# 21
# 22
# 23                                     make;video editor
# 24                                           book covers
# 25                                       ad;button;press
# 26
# 27
# 28
# 29
# 30           photo editors;editing options;photo editing
# 31                                               install
# 32
# 33
# 34                                                   ads
# 35
# 36
# 37                          Covers imperfections;filters
# 38
# 39
# 40                                              features
# 41
# 42                  ads popping up;ad pops up;close;last
# 43
# 44                                         photo editing
# 45
# 46
# 47                                   photo editing tools
# 48
# 49                                      take r add;photo
# 50                                    Access to my phone
# 51                                 running in background
# 52                                                   Get
# 53                                 neat collages;editing
# 54                                      load;add;effects
# 55                                          photo editor
# 56                                                editor
# 57                                                babies
# 58                          Photo Editing;editing Photos
# 59
# 60                                             edit pics
# 61                                           results;get
# 62                                   make AMAZING photos
# 63                                                   get
# 64
# 65
# 66                                                   CS6
# 67
# 68                                      airbrush feature
# 69                                  create amazing fotos
# 70                                 think outside;box;get
# 71
# 72                                                advice
# 73
# 74
# 75                                               options
# 76      delete;edited needless photos;accumulate;gallery
# 77   delete just those photos;maintaining;original photo
# 78
# 79                                                frames
# 80
# 81                              picture qualities;frames
# 82                                        detail options
# 83                                         frame options
# 84                                               adverts
# 85
# 86                                          photo editor
# 87
# 88
# 89                                                popups
# 90                                  blur the blur photos
# 91
# 92
# 93                 choose a photo;a blank black screen;a
# 94                        one photo;add in another photo
# 95                                          sum features
# 96
# 97                                     fun with my photo
# 98                                               edit in
# 99                                         inperfections
# 100
# 101                                FONT;change;FONT Text
# 102                                              affects
# 103
# 104
# 105                                                start
# 106
# 107                                             stickers
# 108
# 109
# 110                                     change font size
# 111                                        fix;ugly pics
# 112
# 113                             look;pictures;edit;photo
# 114
# 115                                             editings
# 116
# 117                               install;frames;effects
# 118
# 119                                 creating more effect
# 120                                               picart
# 121                                 redo;format the text
# 122                                               editor
# 123
# 124                                             stickers
# 125                                               loaded
# 126                                        photo editing
# 127
# 128                                    choose some other
# 129                               feel real;effects;eyes
# 130
# 131                                        upload photos
# 132                                          ehancements
# 133                                                write
# 134
# 135                                      default editors
# 136                                       user interface
# 137                                              install
# 138
# 139                                         Making memes
# 140
# 141
# 142             take off unwanted bits captured in;photo
# 143
# 144
# 145                                         opens;closes
# 146
# 147
# 148
# 149
# 150                                           photo edit
# 151
# 152
# 153

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

# %%
shutil.copy("trained_models/RE_BERT_PhotoEditor_iob_epoch_1.model","/content/drive/MyDrive/Colab Notebooks/Modelos")
shutil.copy("PhotoEditor_extracted_reqs.txt","/content/drive/MyDrive/Colab Notebooks")
shutil.copy("test_data_PhotoEditor.txt","/content/drive/MyDrive/Colab Notebooks")
shutil.copy("test_label_PhotoEditor.txt","/content/drive/MyDrive/Colab Notebooks")
# Out:
# '/content/drive/MyDrive/Colab Notebooks/test_label_PhotoEditor.txt'

# %%
import numpy as np
import pandas as pd

def feature_matching(f_pred, f_true): # f_* are arrays of tokens


  if len(f_pred) == 0: return (False,0)
  if len(f_true) == 0: return (False,0)


  n = np.abs(len(f_pred)-len(f_true))

  test_list = f_true
  sub_list = f_pred
  if len(f_pred) > len(f_true):
    test_list = f_pred
    sub_list = f_true

  subset = False
  if(set(sub_list).issubset(set(test_list))): 
      subset = True

  return subset,n


def metrics(review_f_pred,review_f_true,n): # list of predicted features

  TP = 0
  FP = 0
  FN = 0


  # case 1 (1 predicted and 1 labeled)
  if len(review_f_pred) == len(review_f_true) and len(review_f_true)==1:
    f_pred = review_f_pred[0]
    f_true = review_f_true[0]
    matching = feature_matching(f_pred,f_true)
    if matching[0] == False or matching[1] > n:
      FP+=1
      FN+=1
    if matching[0] == True and matching[1] <= n: TP+=1
    return (TP,FP,FN)

  # case 2 (x predicted and y labeled, with x > 1, and y > 1)
  ## computing TP
  for f_pred in review_f_pred:
    for f_true in review_f_true:
      matching = feature_matching(f_pred,f_true)
      if matching[0] == True and matching[1] <= n: TP+=1

  ## computing FP
  for f_pred in review_f_pred:
    FP_flag = 1
    for f_true in review_f_true:
      matching = feature_matching(f_pred,f_true)
      if matching[0] == True and matching[1] <= n:
        FP_flag = 0
        break # try next
    if FP_flag == 1: FP+=1

  ## computing FN
  for f_true in review_f_true:
    FN_flag = 1
    for f_pred in review_f_pred:
      matching = feature_matching(f_pred,f_true)
      if matching[0] == True and matching[1] <= n:
        FN_flag = 0
        break # try next
    if FN_flag == 1: FN+=1

  return (TP,FP,FN)


def f1_measure(features_extracted, features_labeled, n): # list of extracted features from reviews datadaset
  counter = 0

  if len(features_extracted)!=len(features_labeled):
    return None

  eval_statistics = []
  for counter in range(0,len(features_extracted)):
    txt_features_extracted = features_extracted[counter].split(';')
    txt_features_labeled = features_labeled[counter].split(';')

    review_f_pred = []
    review_f_true = []
    for item in txt_features_extracted: review_f_pred.append( item.split(' ') )
    for item in txt_features_labeled: review_f_true.append( item.split(' ') )


    metric = metrics(review_f_pred, review_f_true, n)
    eval_statistics.append(metric)

    counter += 1

  metrics_sum = pd.DataFrame(eval_statistics).rename(columns={0:'TP',1:'FP',2:'FN'}).sum()
  TP = metrics_sum['TP']
  FP = metrics_sum['FP']
  FN = metrics_sum['FN']

  precision = TP / (TP+FP)
  recall = TP / (TP+FN)
  f1 = (2*precision*recall) / (precision+recall)

  return precision,recall,f1

# %%
f = open("PhotoEditor_extracted_reqs.txt", 'r')
test_data = f.readlines()
f.close()
print("Test Size:", len(test_data))
# Out:
# Test Size: 154

# %%
print("dados:", test_data)
# Out:
# dados: ['check\n', '\n', 'pics look;look at;instagran account\n', '\n', 'install\n', 'ads;interface\n', 'uninstalled\n', '\n', '\n', '\n', '\n', '\n', 'pictures\n', 'options;choose;make whatever kind;picture\n', '\n', 'HD effect;brightness;color correction features\n', 'change;whole pic\n', '\n', 'photos editer\n', '\n', 'stuff\n', '\n', '\n', 'make;video editor\n', 'book covers\n', 'ad;button;press\n', '\n', '\n', '\n', '\n', 'photo editors;editing options;photo editing\n', 'install\n', '\n', '\n', 'ads\n', '\n', '\n', 'Covers imperfections;filters\n', '\n', '\n', 'features\n', '\n', 'ads popping up;ad pops up;close;last\n', '\n', 'photo editing\n', '\n', '\n', 'photo editing tools\n', '\n', 'take r add;photo\n', 'Access to my phone\n', 'running in background\n', 'Get\n', 'neat collages;editing\n', 'load;add;effects\n', 'photo editor\n', 'editor\n', 'babies\n', 'Photo Editing;editing Photos\n', '\n', 'edit pics\n', 'results;get\n', 'make AMAZING photos\n', 'get\n', '\n', '\n', 'CS6\n', '\n', 'airbrush feature\n', 'create amazing fotos\n', 'think outside;box;get\n', '\n', 'advice\n', '\n', '\n', 'options\n', 'delete;edited needless photos;accumulate;gallery\n', 'delete just those photos;maintaining;original photo\n', '\n', 'frames\n', '\n', 'picture qualities;frames\n', 'detail options\n', 'frame options\n', 'adverts\n', '\n', 'photo editor\n', '\n', '\n', 'popups\n', 'blur the blur photos\n', '\n', '\n', 'choose a photo;a blank black screen;a\n', 'one photo;add in another photo\n', 'sum features\n', '\n', 'fun with my photo\n', 'edit in\n', 'inperfections\n', '\n', 'FONT;change;FONT Text\n', 'affects\n', '\n', '\n', 'start\n', '\n', 'stickers\n', '\n', '\n', 'change font size\n', 'fix;ugly pics\n', '\n', 'look;pictures;edit;photo\n', '\n', 'editings\n', '\n', 'install;frames;effects\n', '\n', 'creating more effect\n', 'picart\n', 'redo;format the text\n', 'editor\n', '\n', 'stickers\n', 'loaded\n', 'photo editing\n', '\n', 'choose some other\n', 'feel real;effects;eyes\n', '\n', 'upload photos\n', 'ehancements\n', 'write\n', '\n', 'default editors\n', 'user interface\n', 'install\n', '\n', 'Making memes\n', '\n', '\n', 'take off unwanted bits captured in;photo\n', '\n', '\n', 'opens;closes\n', '\n', '\n', '\n', '\n', 'photo edit\n', '\n', '\n', '\n']

# %%
features_extracted=list()
for predict in test_data:
    feature = predict.strip()
    features_extracted.append(feature)
print(features_extracted)
# Out:
# ['check', '', 'pics look;look at;instagran account', '', 'install', 'ads;interface', 'uninstalled', '', '', '', '', '', 'pictures', 'options;choose;make whatever kind;picture', '', 'HD effect;brightness;color correction features', 'change;whole pic', '', 'photos editer', '', 'stuff', '', '', 'make;video editor', 'book covers', 'ad;button;press', '', '', '', '', 'photo editors;editing options;photo editing', 'install', '', '', 'ads', '', '', 'Covers imperfections;filters', '', '', 'features', '', 'ads popping up;ad pops up;close;last', '', 'photo editing', '', '', 'photo editing tools', '', 'take r add;photo', 'Access to my phone', 'running in background', 'Get', 'neat collages;editing', 'load;add;effects', 'photo editor', 'editor', 'babies', 'Photo Editing;editing Photos', '', 'edit pics', 'results;get', 'make AMAZING photos', 'get', '', '', 'CS6', '', 'airbrush feature', 'create amazing fotos', 'think outside;box;get', '', 'advice', '', '', 'options', 'delete;edited needless photos;accumulate;gallery', 'delete just those photos;maintaining;original photo', '', 'frames', '', 'picture qualities;frames', 'detail options', 'frame options', 'adverts', '', 'photo editor', '', '', 'popups', 'blur the blur photos', '', '', 'choose a photo;a blank black screen;a', 'one photo;add in another photo', 'sum features', '', 'fun with my photo', 'edit in', 'inperfections', '', 'FONT;change;FONT Text', 'affects', '', '', 'start', '', 'stickers', '', '', 'change font size', 'fix;ugly pics', '', 'look;pictures;edit;photo', '', 'editings', '', 'install;frames;effects', '', 'creating more effect', 'picart', 'redo;format the text', 'editor', '', 'stickers', 'loaded', 'photo editing', '', 'choose some other', 'feel real;effects;eyes', '', 'upload photos', 'ehancements', 'write', '', 'default editors', 'user interface', 'install', '', 'Making memes', '', '', 'take off unwanted bits captured in;photo', '', '', 'opens;closes', '', '', '', '', 'photo edit', '', '', '']

# %%
f = open("test_label_PhotoEditor.txt", 'r')
test_data = f.readlines()
f.close()
print("Test Size:", len(test_data))
print("dados:", test_data)
# Out:
# Test Size: 154
# dados: ['\n', '\n', 'pics\n', '\n', 'install\n', 'ads;interface\n', 'uninstalled\n', '\n', '\n', '\n', '\n', '\n', 'pictures\n', 'options to choose from;make whatever kind of picture\n', '\n', 'HD effect;brightness correction;color correction\n', 'change the whole pic\n', '\n', 'photos editer\n', '\n', '\n', 'splash functn;focus functn\n', '\n', 'make a video editor\n', 'book covers\n', '\n', '\n', '\n', '\n', '\n', 'photo editing;photo editors;editing\n', 'effects;install\n', '\n', '\n', 'ads\n', '\n', '\n', 'filters;Covers imperfections\n', '\n', '\n', '\n', '\n', 'ads popping up;ad pops up\n', '\n', 'photo editing\n', '\n', '\n', 'photo editing\n', '\n', 'take photo;add to photo\n', '\n', '\n', '\n', 'editing\n', 'effects\n', 'photo editor;effects\n', 'editor\n', '\n', 'Photo Editing;editing Photos\n', '\n', 'edit pics\n', 'the results I get\n', 'make AMAZING photos\n', '\n', 'rate me pls always pops out\n', '\n', '\n', '\n', 'airbrush feature\n', 'create amazing fotos\n', '\n', '\n', '\n', '\n', '\n', '\n', 'delete previously edited needless photos;gallery\n', 'delete just those photos;maintaining the original photo\n', '\n', 'frames\n', '\n', 'enhanced picture qualities;frames\n', 'detail options\n', 'frame options\n', 'adverts\n', '\n', 'photo editor\n', '\n', '\n', 'popups\n', 'option to un blur the blur photos\n', '\n', '\n', 'choose a photo;black screen came up\n', 'photo;add in another photo\n', '\n', '\n', 'photo\n', 'edit\n', 'perfects flaws;perfects inperfections\n', '\n', 'FONT;change the FONT Text\n', 'affects\n', '\n', '\n', '\n', '\n', 'download the stickers\n', '\n', '\n', 'change font size\n', 'fix my ugly pics\n', '\n', 'pictures;edit one photo;open;closing\n', '\n', 'editings\n', '\n', 'install the frames;effects\n', '\n', 'creating more effect\n', 'picart\n', 'redo the text;format the text\n', 'editor\n', '\n', 'stickers\n', '\n', 'photo editing\n', '\n', '\n', 'effects\n', '\n', 'upload photos\n', 'ehancements\n', '\n', '\n', 'editors\n', 'user interface\n', 'install\n', '\n', 'Making memes\n', '\n', '\n', 'take off unwanted bits captured in the photo\n', '\n', '\n', 'opens;closes\n', '\n', '\n', '\n', '\n', 'photo edit\n', '\n', '\n', '\n']

# %%
features_labeled=list()
for predict in test_data:
    feature = predict.strip()
    features_labeled.append(feature)
print(features_labeled)
# Out:
# ['', '', 'pics', '', 'install', 'ads;interface', 'uninstalled', '', '', '', '', '', 'pictures', 'options to choose from;make whatever kind of picture', '', 'HD effect;brightness correction;color correction', 'change the whole pic', '', 'photos editer', '', '', 'splash functn;focus functn', '', 'make a video editor', 'book covers', '', '', '', '', '', 'photo editing;photo editors;editing', 'effects;install', '', '', 'ads', '', '', 'filters;Covers imperfections', '', '', '', '', 'ads popping up;ad pops up', '', 'photo editing', '', '', 'photo editing', '', 'take photo;add to photo', '', '', '', 'editing', 'effects', 'photo editor;effects', 'editor', '', 'Photo Editing;editing Photos', '', 'edit pics', 'the results I get', 'make AMAZING photos', '', 'rate me pls always pops out', '', '', '', 'airbrush feature', 'create amazing fotos', '', '', '', '', '', '', 'delete previously edited needless photos;gallery', 'delete just those photos;maintaining the original photo', '', 'frames', '', 'enhanced picture qualities;frames', 'detail options', 'frame options', 'adverts', '', 'photo editor', '', '', 'popups', 'option to un blur the blur photos', '', '', 'choose a photo;black screen came up', 'photo;add in another photo', '', '', 'photo', 'edit', 'perfects flaws;perfects inperfections', '', 'FONT;change the FONT Text', 'affects', '', '', '', '', 'download the stickers', '', '', 'change font size', 'fix my ugly pics', '', 'pictures;edit one photo;open;closing', '', 'editings', '', 'install the frames;effects', '', 'creating more effect', 'picart', 'redo the text;format the text', 'editor', '', 'stickers', '', 'photo editing', '', '', 'effects', '', 'upload photos', 'ehancements', '', '', 'editors', 'user interface', 'install', '', 'Making memes', '', '', 'take off unwanted bits captured in the photo', '', '', 'opens;closes', '', '', '', '', 'photo edit', '', '', '']

# %%
f1_measure(features_extracted, features_labeled, 0)
# Out:
# (0.6188118811881188, 0.6944444444444444, 0.6544502617801048)

# %%
f1_measure(features_extracted, features_labeled, 1)
# Out:
# (0.6798029556650246, 0.7582417582417582, 0.7168831168831169)

# %%
f1_measure(features_extracted, features_labeled, 2)
# Out:
# (1.0, 1.0, 1.0)

# %%
f1_measure(features_extracted, features_labeled, 3)
# Out:
# (1.0, 1.0, 1.0)

# %% [markdown]
# Alterando-se o código f1_measure() para testar se algumas passagens fazem diferença:

# %%
f1_measure_changed(features_extracted, features_labeled, 0)
# Out:
# (0.6188118811881188, 0.7961783439490446, 0.6963788300835655)

# %%
f1_measure_changed(features_extracted, features_labeled, 1)
# Out:
# (0.6798029556650246, 0.8518518518518519, 0.7561643835616437)

# %%
f1_measure_changed(features_extracted, features_labeled, 1)
# Out:
# (0.6798029556650246, 0.7582417582417582, 0.7168831168831169)

# %%
import numpy as np
import pandas as pd

def feature_matching(f_pred, f_true): # f_* are arrays of tokens


  if len(f_pred) == 0: return (False,0)
  if len(f_true) == 0: return (False,0)


  n = np.abs(len(f_pred)-len(f_true))

  test_list = f_true
  sub_list = f_pred
  if len(f_pred) > len(f_true):
    test_list = f_pred
    sub_list = f_true

  subset = False
  if(set(sub_list).issubset(set(test_list))): 
      subset = True

  return subset,n


def metrics(review_f_pred,review_f_true,n): # list of predicted features

  TP = 0
  FP = 0
  FN = 0


  # case 1 (1 predicted and 1 labeled)
  if len(review_f_pred) == len(review_f_true) and len(review_f_true)==1:
    f_pred = review_f_pred[0]
    f_true = review_f_true[0]
    matching = feature_matching(f_pred,f_true)
    if matching[0] == False or matching[1] > n:
      FP+=1
      #FN+=1
    if matching[0] == True and matching[1] <= n: TP+=1
    return (TP,FP,FN)

  # case 2 (x predicted and y labeled, with x > 1, and y > 1)
  ## computing TP
  for f_pred in review_f_pred:
    for f_true in review_f_true:
      matching = feature_matching(f_pred,f_true)
      if matching[0] == True and matching[1] <= n: TP+=1

  ## computing FP
  for f_pred in review_f_pred:
    FP_flag = 1
    for f_true in review_f_true:
      matching = feature_matching(f_pred,f_true)
      if matching[0] == True and matching[1] <= n:
        FP_flag = 0
        break # try next
    if FP_flag == 1: FP+=1

  ## computing FN
  for f_true in review_f_true:
    FN_flag = 1
    for f_pred in review_f_pred:
      matching = feature_matching(f_pred,f_true)
      if matching[0] == True and matching[1] <= n:
        FN_flag = 0
        break # try next
    if FN_flag == 1: FN+=1

  return (TP,FP,FN)


def f1_measure_changed(features_extracted, features_labeled, n): # list of extracted features from reviews datadaset

  if len(features_extracted)!=len(features_labeled):
    return None

  eval_statistics = []
  for counter in range(0,len(features_extracted)):
    txt_features_extracted = features_extracted[counter].split(';')
    txt_features_labeled = features_labeled[counter].split(';')

    review_f_pred = []
    review_f_true = []
    for item in txt_features_extracted: review_f_pred.append( item.split(' ') )
    for item in txt_features_labeled: review_f_true.append( item.split(' ') )


    metric = metrics(review_f_pred, review_f_true, n)
    eval_statistics.append(metric)

    

  metrics_sum = pd.DataFrame(eval_statistics).rename(columns={0:'TP',1:'FP',2:'FN'}).sum()
  TP = metrics_sum['TP']
  FP = metrics_sum['FP']
  FN = metrics_sum['FN']

  precision = TP / (TP+FP)
  recall = TP / (TP+FN)
  f1 = (2*precision*recall) / (precision+recall)

  return precision,recall,f1
